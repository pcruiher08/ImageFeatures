# %%
import cv2
import numpy as np
import os
import math as m
import re
import pandas as pd
import scipy
from scipy.stats import skew
from scipy.stats import kurtosis
import mahotas
from skimage.feature import local_binary_pattern
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
polygons = {}

# %%
def gauss(vertices):
    n = len(vertices)
    area = 0.0

    for i in range(n):
        x1, y1 = vertices[i]
        x2, y2 = vertices[(i + 1) % n]
        area += x1 * y2 - x2 * y1

    area = abs(area) / 2

    return area

def perimeter_calc(vertices):
    n = len(vertices)

    perimeter = 0.0

    for i in range(n):
        x1, y1 = vertices[i]
        x2, y2 = vertices[(i + 1) % n]
        perimeter += m.sqrt((x2 - x1)**2 + (y2 - y1)**2)
    return perimeter

def calculate_roundness(vertices):
    area = gauss(vertices)
    perimeter = perimeter_calc(vertices)

    roundness = 4 * m.pi * area / perimeter ** 2

    return "{:.4f}".format(roundness)

def compute_color_moments(vertices, img):

    vertices = np.array(vertices)
    polygon = vertices.reshape((-1,1,2)).astype(np.int32)

    #polygon = vertices.reshape((-1,1,2)).astype(np.int32)
    mask = np.zeros_like(img)
    cv2.fillPoly(mask, [polygon], (255,255,255))
    masked_image = cv2.bitwise_and(img, mask)
    gray_mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)

    average_color = cv2.mean(masked_image, mask=gray_mask)
    #BGRg
    #blue green red (gray/neutral)

    std_dev = np.std(masked_image)
    skewnessval = scipy.stats.skew(masked_image.flatten())
    kurt = kurtosis(masked_image.flatten())



    #print("Average color:", average_color)
    #print("std dev", std_dev)
    #print("skewness", skewnessval)
    #print("kurtosis", kurt)


    return average_color, std_dev, skewnessval, kurt
    ####

    '''
    
    imagepoly = img.copy()
    average_mask = img.copy()


    cv2.polylines(imagepoly, [polygon], True, (0, 255, 0), thickness=2)

    cv2.fillPoly(average_mask, [polygon], average_color)

    horizontal1 = np.hstack((img, imagepoly))
    horizontal2 = np.hstack((masked_image, average_mask))

    vertical = np.vstack((horizontal1, horizontal2))

    

    cv2.imshow("Image", vertical)



    cv2.waitKey(0)
    cv2.destroyAllWindows()

    '''



def compute_Zernike(vertices, img):
    vertices = np.array(vertices)
    polygon = vertices.reshape((-1,1,2)).astype(np.int32)
    mask = np.zeros_like(img)
    cv2.fillPoly(mask, [polygon], (255,255,255))
    
    masked_image = cv2.bitwise_and(img, mask)

    gray_mask = cv2.cvtColor(masked_image, cv2.COLOR_BGR2GRAY)

    zernike_moments = mahotas.features.zernike(gray_mask, radius=100, degree=8, cm=(100, 100))
    return zernike_moments.tolist()

def compute_LBP(vertices, img):
    #local binary patterns for texture
    vertices = np.array(vertices)
    polygon = vertices.reshape((-1,1,2)).astype(np.int32)
    mask = np.zeros_like(img)
    cv2.fillPoly(mask, [polygon], (255,255,255))
    
    masked_image = cv2.bitwise_and(img, mask)

    gray_mask = cv2.cvtColor(masked_image, cv2.COLOR_BGR2GRAY)

    lbp = local_binary_pattern(gray_mask, P=8, R=1, method='uniform')

    hist, _ = np.histogram(lbp, bins=np.arange(0, 11), density=True)

    #print("LBP Histogram:", hist)
    return hist.tolist()

def compute_HUMoments(vertices, img):
    vertices = np.array(vertices)
    polygon = vertices.reshape((-1,1,2)).astype(np.int32)
    mask = np.zeros_like(img)
    cv2.fillPoly(mask, [polygon], (255,255,255))
    
    masked_image = cv2.bitwise_and(img, mask)

    gray_mask = cv2.cvtColor(masked_image, cv2.COLOR_BGR2GRAY)

    moments = cv2.moments(gray_mask)

    hu_moments = cv2.HuMoments(moments).flatten()

    #print("Hu Moments:", hu_moments)
    for i in range(0,7):
        hu_moments[i] = -1* m.copysign(1.0, hu_moments[i]) * m.log10(abs(hu_moments[i]))

    
    return hu_moments.tolist()

# %% [markdown]
# # Retrieving features
#
# This section receives the directory of the images and a directory containing the polygons that describe the form of each fruit

# %%
from ultralytics import YOLO

yolomodel = YOLO('yolov8Strawberries.pt')

# %%
import cv2
import numpy as np
import os
import re
#"/Users/pablo/Desktop/Frutas/RaspsSSI.v1i.yolov8/train/images"
image_dir = "/Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images"
annotation_dir = "/Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/labels"


regexpattern = r"strawberry(\d+)"

for image_file in os.listdir(image_dir):
    #print(image_file)
    if image_file.endswith(".jpg"):
        image_path = os.path.join(image_dir, image_file)

        image = cv2.imread(image_path)



        # Predict with the model
        results = yolomodel(image_path)
        points = results[0].masks.xy[0]  # Masks object

        #print("these are the points:",points)
        #print(results[0])

        #results[0].names['0'] = "Raspberry"
        
        #cv2.imshow("result", )
        #print(image.shape)

  
        
        annotation_file = os.path.splitext(image_file)[0] + ".txt"
        imageID = re.search(regexpattern, annotation_file).group(0)[10:]
        #print(imageID)
        #print(annotation_file)

        points = np.array(points).reshape((-1, 2)).astype(np.int32)
        #print(gauss(points))
        
        mean, stddev, skewnessval, kurt = compute_color_moments(points.tolist(), image)

        humoments = compute_HUMoments(points.tolist(), image)


        zernike = compute_Zernike(points.tolist(), image)

        localBinaryPatterns = compute_LBP(points.tolist(), image)
        
        #print(mean, stddev, skewnessval, kurt, humoments, zernike)
        polygons[imageID] = {"coordinates" : points.tolist(), 
                                "area" : gauss(points), 
                                "roundness" : calculate_roundness(points), 
                                "meancolor" : mean,
                                "meanB" : mean[0],
                                "meanG" : mean[1],
                                "meanR" : mean[2],
                                "meangray" : mean[3],

                                "stddev" : stddev,
                                "skewness" : skewnessval,
                                "kurtosis" : kurt,
                                "h0" : humoments[0],
                                "h1" : humoments[1],
                                "h2" : humoments[2],
                                "h3" : humoments[3],
                                "h4" : humoments[4],
                                "h5" : humoments[5],
                                "h6" : humoments[6],
                                "zernike" : zernike,
                                "LBP" : localBinaryPatterns
                                }
# Out:
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry449_jpg.rf.bdbd5487e08558781e2764597d68e65b.jpg: 512x512 1 Strawberry, 187.6ms
# Speed: 1.7ms preprocess, 187.6ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry401_jpg.rf.b965be8bb173d2578319b8d8e92d56f0.jpg: 512x512 1 Strawberry, 158.1ms
# Speed: 0.3ms preprocess, 158.1ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry439_jpg.rf.ebc62e89c918c08d125a918c3d999056.jpg: 512x512 1 Strawberry, 141.0ms
# Speed: 0.3ms preprocess, 141.0ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry69_jpg.rf.25888cfd65509f35119ae1932ed94cfc.jpg: 512x512 1 Strawberry, 163.1ms
# Speed: 0.5ms preprocess, 163.1ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry187_jpg.rf.83dccb49520876954b5a2dae54551056.jpg: 512x512 1 Strawberry, 171.0ms
# Speed: 0.4ms preprocess, 171.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawber
2ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry471_jpg.rf.98911d8045550ec1a9e496120a807cb4.jpg: 512x512 1 Strawberry, 147.4ms
# Speed: 1.0ms preprocess, 147.4ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry71_jpg.rf.7c32b00a86105ed722d6d26c122c1b9a.jpg: 512x512 1 Strawberry, 141.6ms
# Speed: 0.3ms preprocess, 141.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry278_jpg.rf.71d14860b967c83385fcae423361012f.jpg: 512x512 1 Strawberry, 152.1ms
# Speed: 0.3ms preprocess, 152.1ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry404_jpg.rf.18985a98b075783f6401c4d5b57da159.jpg: 512x512 1 Strawberry, 140.1ms
# Speed: 0.4ms preprocess, 140.1ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry127_jpg.rf.d2e94b4fb5c54693a952e1ee7af580fa.jpg: 512x512 1 Strawberry, 140.5ms
# Speed: 0.3ms preprocess, 140.5ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry326_jpg.rf.bc02abebe961ff6a003bf77bca96cf77.jpg: 512x512 1 Strawberry, 146.2ms
# Speed: 0.6ms preprocess, 146.2ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry94_jpg.rf.3988c623d004b083e40076c211e4f783.jpg: 512x512 1 Strawberry, 140.2ms
# Speed: 0.5ms preprocess, 140.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry47_jpg.rf.b4d69c879ad8fc88ef88c129e2885569.jpg: 512x512 1 Strawberry, 141.9ms
# Speed: 0.4ms preprocess, 141.9ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry483_jpg.rf.d90fedc86ebe5109a249adf7dd798c91.jpg: 512x512 1 Strawberry, 139.6ms
# Speed: 0.4ms preprocess, 139.6ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry209_jpg.rf.9f52b6e54596285305b0b5eb225c5471.jpg: 512x512 1 Strawberry, 157.3ms
# Speed: 0.4ms preprocess, 157.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry475_jpg.rf.0541544c731b8cd8485ce3fbe713815d.jpg: 512x512 1 Strawberry, 138.0ms
# Speed: 0.3ms preprocess, 138.0ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry438_jpg.rf.10f9e36fe6bf61d198e7f7fb9a332009.jpg: 512x512 1 Strawberry, 143.5ms
# Speed: 0.2ms preprocess, 143.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry413_jpg.rf.fef1fed561c46e0a6bb075f04175f0c8.jpg: 512x512 1 Strawberry, 140.4ms
# Speed: 0.3ms preprocess, 140.4ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 512)

# %% [markdown]
# # Mosaico para comparar

# %%
'''
import cv2
import numpy as np
import os
import re
#"/Users/pablo/Desktop/Frutas/RaspsSSI.v1i.yolov8/train/images"
image_dir = "/Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images"
annotation_dir = "/Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/labels"


regexpattern = r"strawberry(\d+)"


for image_file in os.listdir(image_dir):
    #print(image_file)
    if image_file.endswith(".jpg"):
        image_path = os.path.join(image_dir, image_file)

        image = cv2.imread(image_path)

        image_path = os.path.join(image_dir, image_file)
        annotation_file = os.path.splitext(image_file)[0] + ".txt"

        annotation_path = os.path.join(annotation_dir, annotation_file)
        #print(annotation_path)
        with open(annotation_path, "r") as f:
            annotations = f.readlines()
            #print(annotations)
        annotatedPoints = []
        for annotation in annotations:
            # Split the annotation into its components
            components = annotation.split()
            class_id = int(components[0])
            coords = []

            for i in range(1, len(components)):
                corrected = 0
                if(i%2 == 0):
                    corrected = float(components[i]) * image.shape[0] 
                else:
                    corrected = float(components[i]) * image.shape[1]
                coords.append(corrected)

            annotatedPoints = np.array(coords).reshape((-1, 2)).astype(np.int32)
        # Predict with the model
        results = yolomodel(image_path)
        points = results[0].masks.xy[0]  # Masks object

        #print("these are the points:",points)
        #print(results[0])

        #results[0].names['0'] = "Raspberry"
        
        #cv2.imshow("result", )
        #print(image.shape)

  
        
        annotation_file = os.path.splitext(image_file)[0] + ".txt"
        imageID = re.search(regexpattern, annotation_file).group(0)
        #print(imageID)
        #print(annotation_file)

        points = np.array(points).reshape((-1, 2)).astype(np.int32)
        #print(gauss(points))
        
        mean, stddev, skewnessval, kurt = compute_color_moments(points.tolist(), image)

        humoments = compute_HUMoments(points.tolist(), image)


        zernike = compute_Zernike(points.tolist(), image)

        localBinaryPatterns = compute_LBP(points.tolist(), image)
        
        #print(mean, stddev, skewnessval, kurt, humoments, zernike)
        

        
        origImage = image.copy()
        annotatedOrigImage = image.copy()

        
        cv2.polylines(image, [points], True, (0, 255, 0), thickness=2)
        cv2.polylines(annotatedOrigImage, [annotatedPoints], True, (0, 255, 0), thickness=2)


        horizontal = np.hstack((results[0].plot(), image))
        horizontal2 = np.hstack((origImage, annotatedOrigImage))
        full = np.vstack((horizontal, horizontal2))


        cv2.imshow("Image", full)
        cv2.waitKey(0)
        #cv2.destroyAllWindows()
'''
# Out:
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry449_jpg.rf.bdbd5487e08558781e2764597d68e65b.jpg: 512x512 1 Strawberry, 270.3ms
# Speed: 1.3ms preprocess, 270.3ms inference, 16.9ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry401_jpg.rf.b965be8bb173d2578319b8d8e92d56f0.jpg: 512x512 1 Strawberry, 193.8ms
# Speed: 1.3ms preprocess, 193.8ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry439_jpg.rf.ebc62e89c918c08d125a918c3d999056.jpg: 512x512 1 Strawberry, 148.3ms
# Speed: 0.5ms preprocess, 148.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry69_jpg.rf.25888cfd65509f35119ae1932ed94cfc.jpg: 512x512 1 Strawberry, 158.0ms
# Speed: 0.6ms preprocess, 158.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry187_jpg.rf.83dccb49520876954b5a2dae54551056.jpg: 512x512 1 Strawberry, 204.2ms
# Speed: 0.8ms preprocess, 204.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry371_jpg.rf.c465e8bf48565aaede1a9c14ae421d8e.jpg: 512x512 1 Strawberry, 143.8ms
# Speed: 0.7ms preprocess, 143.8ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry334_jpg.rf.8df047ca0cd563e592eb2f8a121eab05.jpg: 512x512 1 Strawberry, 160.5ms
# Speed: 0.8ms preprocess, 160.5ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry342_jpg.rf.f22bad19ea0a949cfbfc2bc055d7c54d.jpg: 512x512 1 Strawberry, 169.1ms
# Speed: 0.7ms preprocess, 169.1ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry171_jpg.rf.a6db5f5cb72b1fe9af5307f52d1b78f7.jpg: 512x512 1 Strawberry, 166.0ms
# Speed: 0.7ms preprocess, 166.0ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry356_jpg.rf.2071a0340aebc8ada7297baa48c66a4a.jpg: 512x512 1 Strawberry, 170.8ms
# Speed: 0.5ms preprocess, 170.8ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry29_jpg.rf.8ef6ea2ca18a79585852f55443149dda.jpg: 512x512 1 Strawberry, 143.0ms
# Speed: 0.7ms preprocess, 143.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry340_jpg.rf.4caf5ce9c29c525126229542f41feae9.jpg: 512x512 1 Strawberry, 159.1ms
# Speed: 0.6ms preprocess, 159.1ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry157_jpg.rf.ea452cc5f00b9ea01f32f6183fd175d2.jpg: 512x512 1 Strawberry, 151.2ms
# Speed: 0.6ms preprocess, 151.2ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawber
ms preprocess, 148.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry469_jpg.rf.78b5997506a9ffd41ae5c03058fb1d1a.jpg: 512x512 1 Strawberry, 150.2ms
# Speed: 0.6ms preprocess, 150.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry159_jpg.rf.d98291e82e5a580a55cd78df0b411ff0.jpg: 512x512 1 Strawberry, 150.6ms
# Speed: 0.5ms preprocess, 150.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry380_jpg.rf.98190b1ca5a1e6197da15b703e297443.jpg: 512x512 1 Strawberry, 155.2ms
# Speed: 0.5ms preprocess, 155.2ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry287_jpg.rf.af60394ad97a8b05d84b17dd95b0adb9.jpg: 512x512 1 Strawberry, 149.9ms
# Speed: 0.5ms preprocess, 149.9ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry261_jpg.rf.d18547c77ff9a8cbf5f674765a9de145.jpg: 512x512 1 Strawberry, 152.0ms
# Speed: 0.7ms preprocess, 152.0ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry24_jpg.rf.33385675bd5c54b16ba642aee1f1cdd3.jpg: 512x512 1 Strawberry, 148.6ms
# Speed: 0.6ms preprocess, 148.6ms inference, 1.5ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry233_jpg.rf.a3c6fa4f6e727d97eec3103a5adc9972.jpg: 512x512 1 Strawberry, 152.9ms
# Speed: 0.6ms preprocess, 152.9ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry49_jpg.rf.51d9443898a76bbff78484f7b920a7e1.jpg: 512x512 1 Strawberry, 151.6ms
# Speed: 0.8ms preprocess, 151.6ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry474_jpg.rf.73ae1d1d90294f6a6da0c094d7212b4a.jpg: 512x512 1 Strawberry, 152.0ms
# Speed: 0.8ms preprocess, 152.0ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry465_jpg.rf.0650ef3f5d8cb27fd328d231b21c6121.jpg: 512x512 1 Strawberry, 170.4ms
# Speed: 0.7ms preprocess, 170.4ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry485_jpg.rf.5e1cbab7a37eb5f52a35ef880f1e9368.jpg: 512x512 1 Strawberry, 149.1ms
# Speed: 0.6ms preprocess, 149.1ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry309_jpg.rf.d750142fd9cf2404ef0dedc63df537f5.jpg: 512x512 1 Strawberry, 146.4ms
# Speed: 0.5ms preprocess, 146.4ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 512)
#
# image 1/1 /Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/Strawberries.v1i.yolov8/train/images/strawberry431_jpg.rf.3a94c3f768b844484ce2c8a34671567c.jpg: 512x512 1 Strawberry, 161.3ms
# Speed: 0.6ms preprocess, 161.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 512)

# %%
IDAndArea = {}
IDAndCoordinates = {}
IDAndRoundness = {}

IDAndMeanColor = {}
IDAndMeanB = {}
IDAndMeanG = {}
IDAndMeanR = {}
IDAndMeanGray = {}
 
IDAndSTDDev = {}
IDAndSkewness = {}
IDAndKurtosis = {}

IDAndHUMoments = {}
IDAndHus = {}
IDAndH0 = {}
IDAndH1 = {}
IDAndH2 = {}
IDAndH3 = {}
IDAndH4 = {}
IDAndH5 = {}
IDAndH6 = {}

IDAndZernike = {}
IDAndLBP = {}

for elem in polygons:
    IDAndArea[elem] = polygons[elem]["area"]


    IDAndCoordinates[elem] = polygons[elem]["coordinates"]


    IDAndRoundness[elem] = polygons[elem]["roundness"]


    IDAndMeanColor[elem] = polygons[elem]["meancolor"]


    IDAndMeanB[elem] = polygons[elem]["meanB"]

    IDAndMeanG[elem] = polygons[elem]["meanG"]

    IDAndMeanR[elem] = polygons[elem]["meanR"]

    IDAndMeanGray[elem] = polygons[elem]["meangray"]


    IDAndSTDDev[elem] = polygons[elem]["stddev"]


    IDAndSkewness[elem] = polygons[elem]["skewness"]


    IDAndKurtosis[elem] = polygons[elem]["kurtosis"]



    IDAndH0[elem] = polygons[elem]['h0']

    IDAndH1[elem] = polygons[elem]['h1']

    IDAndH2[elem] = polygons[elem]['h2']

    IDAndH3[elem] = polygons[elem]['h3']

    IDAndH4[elem] = polygons[elem]['h4']

    IDAndH5[elem] = polygons[elem]['h5']

    IDAndH6[elem] = polygons[elem]['h6']



    IDAndZernike[elem] = polygons[elem]["zernike"]


    IDAndLBP[elem] = polygons[elem]["LBP"]

'''
print(IDAndArea)
print(IDAndCoordinates)
print(IDAndRoundness)
print(IDAndMeanColor)


print(IDAndSTDDev)
print(IDAndSkewness)
print(IDAndKurtosis)

print("h0",IDAndH0)
print("h1",IDAndH1)
print("h2",IDAndH2)
print("h3",IDAndH3)
print("h4",IDAndH4)
print("h5",IDAndH5)
print("h6",IDAndH6)

print("B",IDAndMeanB)
print("G",IDAndMeanG)
print("R",IDAndMeanR)
print("Gray",IDAndMeanGray)
'''
#print(IDAndZernike)
#print(IDAndLBP)
# Out:
# '\nprint(IDAndArea)\nprint(IDAndCoordinates)\nprint(IDAndRoundness)\nprint(IDAndMeanColor)\n\n\nprint(IDAndSTDDev)\nprint(IDAndSkewness)\nprint(IDAndKurtosis)\n\nprint("h0",IDAndH0)\nprint("h1",IDAndH1)\nprint("h2",IDAndH2)\nprint("h3",IDAndH3)\nprint("h4",IDAndH4)\nprint("h5",IDAndH5)\nprint("h6",IDAndH6)\n\nprint("B",IDAndMeanB)\nprint("G",IDAndMeanG)\nprint("R",IDAndMeanR)\nprint("Gray",IDAndMeanGray)\n'

# %% [markdown]
# # Area

# %%
areadf = pd.Series(IDAndArea).to_frame().reset_index()
areadf.columns = ['ID', 'AreaInSquaredPixels']
areadf['ID'] = areadf['ID'].astype(int)
areadf['AreaInSquaredPixels'] = areadf['AreaInSquaredPixels'].astype(float)


areadf = areadf.sort_values('ID')
areadf = areadf.reset_index(drop=True)

areadf.head(10)
# Out:
#    ID  AreaInSquaredPixels
# 0   1              58097.5
# 1   2              57949.0
# 2   3              58149.5
# 3   4              58848.0
# 4   5              56919.0
# 5   6              58032.0
# 6   7              58383.5
# 7   8              58205.0
# 8   9              57218.5
# 9  10              58101.5

# %% [markdown]
# # Roundness

# %%
roundnessdf = pd.Series(IDAndRoundness).to_frame().reset_index()
roundnessdf.columns = ['ID', 'Roundness']
roundnessdf['ID'] = roundnessdf['ID'].astype(int)
roundnessdf['Roundness'] = roundnessdf['Roundness'].astype(float)


roundnessdf = roundnessdf.sort_values('ID')
roundnessdf = roundnessdf.reset_index(drop=True)

roundnessdf.head(10)
# Out:
#    ID  Roundness
# 0   1     0.3735
# 1   2     0.3770
# 2   3     0.3732
# 3   4     0.4448
# 4   5     0.4797
# 5   6     0.4189
# 6   7     0.4051
# 7   8     0.4191
# 8   9     0.3137
# 9  10     0.3416

# %% [markdown]
# # Mass

# %%
def calculate_average_mass(df_row):
    sum_of_weights = 0

    for i in range(1,len(df_row)):
        sum_of_weights += float(df_row[i])
        average = sum_of_weights / (len(df_row) - 1)
    return "{:.4f}".format(average)

def rename_image(df_row):
    newname = df_row['Image'].replace("strawberry", "")

    return newname

def get_index(df_row):
    return df_row['Image'][:len(df_row['Image']) - 4]

# %%
weightsFileName = '/Users/pablo/Documents/Programacion/StrawberriesImageMassDataset/weightsStrawberries.txt'

df = pd.read_csv(weightsFileName, header=None, delim_whitespace=True)

df.rename(columns = {0:'Image'}, 
            inplace = True)

df['AverageMass'] = df.apply(calculate_average_mass, axis=1)

df['Image'] = df.apply(rename_image, axis=1)

df['ID'] = df.apply(get_index, axis=1)

mass = pd.DataFrame().assign(Image=df['Image'], ID=df['ID'], 
                            Weigh1=df[1],
                            Weigh2=df[2],
                            Weigh3=df[3],
                            Weigh4=df[4],
                            Weigh5=df[5],
                            Weigh6=df[6],
                            Weigh7=df[7],
                            Weigh8=df[8],
                            Weigh9=df[9],
                            Weigh10=df[10],
                            Weigh11=df[11],
                            AverageMass=df['AverageMass'])
mass['ID'] = mass['ID'].astype(int)
mass['AverageMass'] = mass['AverageMass'].astype(float)
mass.to_json('massStraws.json', orient = 'split', compression = 'infer', index = 'true')
mass.head(10)
latex_table = mass.head(10).to_latex(index=False, bold_rows=True, caption="Table of image Weighs and Average Mass")

#print(latex_table)

# %% [markdown]
# # Classic Geometry

# %%
classicgeometry = pd.merge(areadf[['ID', 'AreaInSquaredPixels']], mass[['ID', 'AverageMass']], on='ID', how='inner')

classicgeometry = pd.merge(classicgeometry[['ID', 'AverageMass', 'AreaInSquaredPixels']], roundnessdf[['ID', 'Roundness']], on='ID', how='inner')

classicgeometry.to_csv('classicgeometryYOLORasp.csv', index = False)

classicgeometry.head(5)

#print(latex_table)
# Out:
#    ID  AverageMass  AreaInSquaredPixels  Roundness
# 0   1       4.8566              19512.5     0.8571
# 1   2       4.8568              19716.0     0.8673
# 2   3       4.8654              19595.5     0.8522
# 3   4       4.8691              19770.5     0.8534
# 4   5       4.8689              19784.0     0.8649

# %% [markdown]
# # Hu Moments

# %%
hu0 = pd.Series(IDAndH0).to_frame().reset_index()
hu0.columns = ['ID', 'hu0']
hu0['ID'] = hu0['ID'].astype(int)
hu0['hu0'] = hu0['hu0'].astype(float)
hu0 = hu0.sort_values('ID')
hu0 = hu0.reset_index(drop=True)

#print(hu0.head(10))

hu1 = pd.Series(IDAndH1).to_frame().reset_index()
hu1.columns = ['ID', 'hu1']
hu1['ID'] = hu1['ID'].astype(int)
hu1['hu1'] = hu1['hu1'].astype(float)
hu1 = hu1.sort_values('ID')
hu1 = hu1.reset_index(drop=True)

#print(hu1.head(10))

hu2 = pd.Series(IDAndH2).to_frame().reset_index()
hu2.columns = ['ID', 'hu2']
hu2['ID'] = hu2['ID'].astype(int)
hu2['hu2'] = hu2['hu2'].astype(float)
hu2 = hu2.sort_values('ID')
hu2 = hu2.reset_index(drop=True)

#print(hu2.head(10))

hu3 = pd.Series(IDAndH2).to_frame().reset_index()
hu3.columns = ['ID', 'hu3']
hu3['ID'] = hu3['ID'].astype(int)
hu3['hu3'] = hu3['hu3'].astype(float)
hu3 = hu3.sort_values('ID')
hu3 = hu3.reset_index(drop=True)

#print(hu3.head(10))

hu4 = pd.Series(IDAndH4).to_frame().reset_index()
hu4.columns = ['ID', 'hu4']
hu4['ID'] = hu4['ID'].astype(int)
hu4['hu4'] = hu4['hu4'].astype(float)
hu4 = hu4.sort_values('ID')
hu4 = hu4.reset_index(drop=True)

#print(hu4.head(10))


hu5 = pd.Series(IDAndH5).to_frame().reset_index()
hu5.columns = ['ID', 'hu5']
hu5['ID'] = hu5['ID'].astype(int)
hu5['hu5'] = hu5['hu5'].astype(float)
hu5 = hu5.sort_values('ID')
hu5 = hu5.reset_index(drop=True)

#print(hu5.head(10))


hu6 = pd.Series(IDAndH6).to_frame().reset_index()
hu6.columns = ['ID', 'hu6']
hu6['ID'] = hu6['ID'].astype(int)
hu6['hu6'] = hu6['hu6'].astype(float)
hu6 = hu6.sort_values('ID')
hu6 = hu6.reset_index(drop=True)

#print(hu6.head(10))
humoments = pd.merge(hu0[['ID', 'hu0']], mass[['ID', 'AverageMass']], on='ID', how='inner')

humoments = pd.merge(humoments[['ID', 'AverageMass', 'hu0']], hu1[['ID', 'hu1']], on='ID', how='inner')

humoments = pd.merge(humoments[['ID', 'AverageMass', 'hu0', 'hu1']], hu2[['ID', 'hu2']], on='ID', how='inner')
humoments = pd.merge(humoments[['ID', 'AverageMass', 'hu0', 'hu1', 'hu2']], hu3[['ID', 'hu3']], on='ID', how='inner')
humoments = pd.merge(humoments[['ID', 'AverageMass', 'hu0', 'hu1', 'hu2', 'hu3']], hu4[['ID', 'hu4']], on='ID', how='inner')
humoments = pd.merge(humoments[['ID', 'AverageMass', 'hu0', 'hu1', 'hu2', 'hu3', 'hu4']], hu5[['ID', 'hu5']], on='ID', how='inner')
humoments = pd.merge(humoments[['ID', 'AverageMass', 'hu0', 'hu1', 'hu2', 'hu3', 'hu4', 'hu5']], hu6[['ID', 'hu6']], on='ID', how='inner')


humoments.to_csv('humomentsYOLORasp.csv', index = False)

humoments.head(5)
#
#0	1	2	3	4	5	6
#469	2.669828	6.950577	10.427229	10.260607	-20.705395	-13.776959	20.819507
#humoments.loc[468]

#print(latex_table)
# Out:
#    ID  AverageMass       hu0       hu1        hu2        hu3        hu4
# 0   1       4.8566  2.673033  7.010661  10.229825  10.229825  21.852097  \
# 1   2       4.8568  2.645191  6.989123   9.823755   9.823755 -20.681373
# 2   3       4.8654  2.661717  6.901214  10.126616  10.126616 -21.688223
# 3   4       4.8691  2.679435  7.465285  10.078639  10.078639 -22.324437
# 4   5       4.8689  2.657988  7.188936   9.928998   9.928998 -22.088880
#
#          hu5        hu6
# 0  15.126325  22.082975
# 1  14.374104 -20.827661
# 2 -15.053662 -20.861062
# 3  14.268356  20.842234
# 4 -14.932566 -22.112530

# %% [markdown]
# # Color

# %%
meanB = pd.Series(IDAndMeanB).to_frame().reset_index()
meanB.columns = ['ID', 'meanB']
meanB['ID'] = meanB['ID'].astype(int)
meanB['meanB'] = meanB['meanB'].astype(float)
meanB = meanB.sort_values('ID')
meanB = meanB.reset_index(drop=True)

#print(meanB.head(10))

meanG = pd.Series(IDAndMeanG).to_frame().reset_index()
meanG.columns = ['ID', 'meanG']
meanG['ID'] = meanG['ID'].astype(int)
meanG['meanG'] = meanG['meanG'].astype(float)
meanG = meanG.sort_values('ID')
meanG = meanG.reset_index(drop=True)

#print(meanG.head(10))

meanR = pd.Series(IDAndMeanR).to_frame().reset_index()
meanR.columns = ['ID', 'meanR']
meanR['ID'] = meanR['ID'].astype(int)
meanR['meanR'] = meanR['meanR'].astype(float)
meanR = meanR.sort_values('ID')
meanR = meanR.reset_index(drop=True)

#print(meanR.head(10))

meanGray = pd.Series(IDAndMeanGray).to_frame().reset_index()
meanGray.columns = ['ID', 'meangray']
meanGray['ID'] = meanGray['ID'].astype(int)
#meanGray['meangray'] = meanGray['meangray'].astype(float)
meanGray = meanGray.sort_values('ID')
meanGray = meanGray.reset_index(drop=True)

#print(meanGray.head(10))

colors = pd.merge(meanB[['ID', 'meanB']], mass[['ID', 'AverageMass']], on='ID', how='inner')

colors = pd.merge(colors[['ID', 'AverageMass','meanB']], meanG[['ID', 'meanG']], on='ID', how='inner')
colors = pd.merge(colors[['ID', 'AverageMass','meanB', 'meanG']], meanR[['ID', 'meanR']], on='ID', how='inner')
#colors = pd.merge(colors[['ID', 'AverageMass','meanB', 'meanG', 'meanR']], meanGray[['ID', 'meangray']], on='ID', how='inner')

colors.to_csv('colorsYOLORasp.csv', index = False)


colors.head(5)

#print(latex_table)
# Out:
#    ID  AverageMass      meanB      meanG       meanR
# 0   1       4.8566  32.859581  47.789700  158.103808
# 1   2       4.8568  29.388143  42.828957  151.619174
# 2   3       4.8654  31.607341  45.915045  155.818342
# 3   4       4.8691  34.260420  49.282959  159.301299
# 4   5       4.8689  30.567126  45.603636  154.491110

# %% [markdown]
# # All data

# %%
allfeatures = pd.merge(classicgeometry[['ID', 'AverageMass', 'AreaInSquaredPixels', 'Roundness']], humoments[['ID', 'hu0', 'hu1', 'hu2', 'hu3', 'hu4', 'hu5', 'hu6']], on='ID', how='inner')
allfeatures = pd.merge(allfeatures[['ID', 'AverageMass', 'AreaInSquaredPixels', 'Roundness', 'hu0', 'hu1', 'hu2', 'hu3', 'hu4', 'hu5', 'hu6']], colors[['ID', 'meanB', 'meanG', 'meanR']], on='ID', how='inner')


allfeatures.to_csv('allfeaturesYOLORasp.csv', index = False)

allfeatures.head(5)
# Out:
#    ID  AverageMass  AreaInSquaredPixels  Roundness       hu0       hu1
# 0   1       4.8566              19512.5     0.8571  2.673033  7.010661  \
# 1   2       4.8568              19716.0     0.8673  2.645191  6.989123
# 2   3       4.8654              19595.5     0.8522  2.661717  6.901214
# 3   4       4.8691              19770.5     0.8534  2.679435  7.465285
# 4   5       4.8689              19784.0     0.8649  2.657988  7.188936
#
#          hu2        hu3        hu4        hu5        hu6      meanB
# 0  10.229825  10.229825  21.852097  15.126325  22.082975  32.859581  \
# 1   9.823755   9.823755 -20.681373  14.374104 -20.827661  29.388143
# 2  10.126616  10.126616 -21.688223 -15.053662 -20.861062  31.607341
# 3  10.078639  10.078639 -22.324437  14.268356  20.842234  34.260420
# 4   9.928998   9.928998 -22.088880 -14.932566 -22.112530  30.567126
#
#        meanG       meanR
# 0  47.789700  158.103808
# 1  42.828957  151.619174
# 2  45.915045  155.818342
# 3  49.282959  159.301299
# 4  45.603636  154.491110
